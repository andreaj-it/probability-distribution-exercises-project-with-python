# %% [markdown]
# # Probability Distribution Problems

# %% [markdown]
# **Binomial Distribution**
#
# In probability theory and statistics, the binomial distribution is the discrete probability distribution that gives only two possible results in an experiment, for example, when you flip a coin it can by either Head or Tails.

# %%
# Probability functions, density and distribution

def dbinom(x,size,prob=0.5):
    """
    Calculates the point estimate of the binomial distribution
    """
    from scipy.stats import binom
    result=binom.pmf(k=x,n=size,p=prob,loc=0)
    return result

def pbinom(q,size,prob=0.5):
    """
    Calculates the cumulative of the binomial distribution
    """
    from scipy.stats import binom
    result=binom.cdf(k=q,n=size,p=prob,loc=0)
    return result

def qbinom(p, size, prob=0.5):
    """
    Calculates the quantile function from the binomial distribution
    """
    from scipy.stats import binom
    result=binom.ppf(q=p,n=size,p=prob,loc=0)
    return result

def rbinom(n,size,prob=0.5):
    """
    Generates random variables from the binomial distribution
    """
    from scipy.stats import binom
    result=binom.rvs(n=size,p=prob,size=n)
    return result

# %%
dbinom(2, size = 10, prob = 0.2) #Probability that a binomial (10,0.2) takes the value 2,
pbinom(2, size = 10, prob = 0.2) #Probability that a binomial (10,0.2) will take a value less than 2
qbinom(0.9, size = 10, prob = 0.2) # what value of a binomial (10,0.2) has a cumulative probability of 0.9?
rbinom(2000, size = 10, prob = 0.2) # generate 2000 random values from a binomial distribution (10,0.2)
# Out:
# array([1, 1, 2, ..., 3, 3, 2])

# %%
import numpy as np
import matplotlib.pyplot as plt

# Discrete distributions
xs = np.arange( 1, 11 )
ys = dbinom(xs,size=10,prob=0.5) # compute the shape of the distribution
plt.plot( xs, ys, 'o' )   # plot circles...
plt.vlines( xs, 0, ys )   # ...and lines
plt.ylim( bottom=0 )      # ensure sensible bottom border
plt.title('Probability function binomial distribution')
plt.show()

# %% [markdown]
# Exercise 1: Create the same functions but for the normal and uniform distribution.

# %%
#pasar los parametros que usa la normal y se aplica la formula, solo usa la media y desviacion estandar
def dnormal(x,mean=0,sd =1):
    #campana de gaus, probalilidad q caiga en ese intervalo, formula de densidad
    #density of the Normal distribution
    from scipy.stats import norm
    result=norm.pdf(x,loc=mean,scale=sd)
    return result

# %%
dnormal(2,1,1)
# Out:
# 0.24197072451914337

# %%
def pnormal(x,mean=0,sd =1):
  #cumulative of the Normal distribution
    from scipy.stats import norm
    result=norm.cdf(x,loc=mean,scale=sd)
    return result

# %%
pnormal(2,1,1)
# Out:
# 0.8413447460685429

# %%
def qnormal(x,mean=0,sd =1):
    # quantile function from the Normal distribution
    from scipy.stats import norm
    result=norm.ppf(x,loc=mean,scale=sd)
    #norm.ppf(0.95, loc=0, scale=1)
    #The method norm.ppf() takes a percentage and returns a standard deviation multiplier for what value that percentage occurs at.
    return result

# %%
qnormal(0.95)
# Out:
# 1.6448536269514722

# %%
def rnormal(x,mean=0,sd =1):
    #Generates random variables from the Normal distribution
    from scipy.stats import norm
    result=norm.rvs(size=x,loc=mean,scale=sd)
    #rvs(loc=0, scale=1, size=1)
    #A normal continuous random variable. The location (loc) keyword specifies the mean. The scale (scale) keyword specifies the standard deviation.
    return result

# %%
rnormal(2)
# Out:
# array([-0.18076388,  0.15664428])

# %%
# dNormal
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(-10,10,0.1)
y = plt.plot(x,dnormal(x,mean=0,sd=1))

plt.ylim( bottom=0 )     
plt.title('Probability function normal distribution')
plt.show()

# %%
plt.plot(x,pnormal(x,mean=0,sd=1))

# %%
plt.plot(x,qnormal(x,mean=0,sd=1))

# %%
#hacer todo de nuevo ahora con los metodos de uniforme
#from scipy.stats import uniform
#scipy.stats.uniform.pdf(x, loc=0, scale=1)
#scipy.stats.uniform.cdf(x, loc=0, scale=1)
#scipy.stats.uniform.ppf(q, loc=0, scale=1)
#scipy.stats.uniform.rvs(loc=0, scale=1, size=1)

def duniforme(x,mean=0,sd =1):
    from scipy.stats import uniform
    result=uniform.pdf(x,loc=mean,scale=sd)
    return result

# %%
duniforme(2,1,1)
# Out:
# 1.0

# %%
def puniforme(x,mean=0,sd =1):
  #cumulative of the Uniforme distribution
    from scipy.stats import uniform
    result=uniform.cdf(x,loc=mean,scale=sd)
    return result

# %%
puniforme(2,1,1)
# Out:
# 1.0

# %%
def quniforme(x,mean=0,sd =1):
    from scipy.stats import uniform
    result=uniform.ppf(x,loc=mean,scale=sd)
    return result

# %%
quniforme(0.95)
# Out:
# 0.95

# %%
def runiforme(x,mean=0,sd =1):
    from scipy.stats import uniform
    result=uniform.rvs(size=x,loc=mean,scale=sd)
    return result

# %%
runiforme(2)
# Out:
# array([0.18323719, 0.12061139])

# %%
x = np.arange(-15,15,0.4)
plt.plot(x,duniforme(x,mean=0,sd=1))

# %%
plt.plot(x,puniforme(x,mean=0,sd=1))

# %%
plt.plot(x,quniforme(x,mean=0,sd=1))
